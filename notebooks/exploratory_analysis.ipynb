# %% [markdown]
# # Explore a completed run
# All processing lives in reusable modules. Synthetic results verify software only.

# %%
from pathlib import Path
import pandas as pd
from IPython.display import display, Image

run = Path("../results/demo")
display(pd.read_csv(run / "tables/metrics.csv"))
display(pd.read_csv(run / "tables/paired_differences.csv"))
display(Image(filename=str(run / "figures/performance.png")))
